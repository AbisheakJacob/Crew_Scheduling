# %%
# importing the packages
import numpy as np
import pandas as pd
from pairing_generation.duty_generation import generate_duties

# %% [markdown]
# The algorithm iterates through the duty generation algo and the column generation algo
#
# these two algo have to be modifided such that they will the depth in an iterative fashion and then operate in a modular fashion
#
# - modify the duty generation algorithm for a depth of 2 and 3
# - modify the pairing generation algorithm in an iterative fashion of depth 3, 4 and 5

# %%
# Reading the dataframe and converting it to a numpy array
np_arr = pd.read_csv(
    "data/flight_legs/data.csv",
    parse_dates=["start_time", "end_time"],
).to_numpy()

num_flights = np_arr.shape[0]

# %%
generate_duties(3)

# %%
# write the algorithm to iterate over duties and pairings
# Out:
# 252

# %%
# calling the algorithms in an iterative fashion
